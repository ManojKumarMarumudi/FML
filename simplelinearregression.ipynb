# %% [markdown]
# <a href="https://colab.research.google.com/github/ManojKumarMarumudi/FML/blob/main/simplelinearregression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
data_set=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Salary_Data.csv")

# %%
data_set.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
data_set.tail()
# Out:
#     YearsExperience  Salary
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 608.0 bytes

# %%
data_set.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
#separating the trainng the and the testing data
x=data_set.iloc[:,:-1]
x
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
y=data_set.iloc[:,1]
y
# Out:
# 0      39343
# 1      46205
# 2      37731
# 3      43525
# 4      39891
# 5      56642
# 6      60150
# 7      54445
# 8      64445
# 9      57189
# 10     63218
# 11     55794
# 12     56957
# 13     57081
# 14     61111
# 15     67938
# 16     66029
# 17     83088
# 18     81363
# 19     93940
# 20     91738
# 21     98273
# 22    101302
# 23    113812
# 24    109431
# 25    105582
# 26    116969
# 27    112635
# 28    122391
# 29    121872
# Name: Salary, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,random_state=15)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)
x_pred=regressor.predict(x_train)

# %%
plt.scatter(x_train,y_train,color="violet")
plt.plot(x_train,x_pred,color="purple")
plt.title("salary vs experience (training dataset)")
plt.xlabel("years of experience")
plt.ylabel("salary")
plt.show()

# %%
plt.scatter(x_test,y_test,color="indigo")
plt.plot(x_test,y_pred,color="red")
plt.title("salary vs experience (training dataset)")
plt.xlabel("years of experience")
plt.ylabel("salary")
plt.show()
